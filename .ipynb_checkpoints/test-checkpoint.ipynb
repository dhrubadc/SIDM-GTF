# %%
import numpy as np
import matplotlib.pyplot as plt
from grid import make_radial_grid, cell_centers, shell_volumes, log_cell_centers, log_shell_volumes
from initial_conditions import nfw_dimensionless, truncated_nfw_dimensionless, enclosed_mass, shell_mass, hydrostatic_u_from_rho

# %%
r_first=0.001
r_max=70.0
N_shell=200

# %%
r_edge = make_radial_grid(r_first, r_max, N_shell)
r = cell_centers(r_edge)
V = shell_volumes(r_edge)

# %%
ln_r_edge = np.log(r_edge)
ln_r = log_cell_centers(ln_r_edge)
ln_V = log_shell_volumes(ln_r_edge)
# Out:
# /var/folders/sq/wmftrzfs7fn7mp6d45b04pm80000gn/T/ipykernel_50745/1899595485.py:1: RuntimeWarning: divide by zero encountered in log
#   ln_r_edge = np.log(r_edge)

# %%
r_edge.dtype, r.dtype, V.dtype, ln_r.dtype, ln_V.dtype
# Out:
# (dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'))

# %%
r_t=40.0
n=5.0
rho = truncated_nfw_dimensionless(r,r_t,n)
dm = shell_mass(rho, V)
M_edge = enclosed_mass(dm)
u = hydrostatic_u_from_rho(r_edge, rho, M_edge, u_outer=0.001)

# %%
rho.dtype, dm.dtype, M_edge.dtype, u.dtype
# Out:
# (dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'))

# %%
fig,ax=plt.subplots(1,4,figsize=(15,5),sharex='all')
ax[0].plot(r,rho)
ax[1].plot(r,dm)
ax[2].plot(r_edge,M_edge)
ax[3].plot(r,u)

ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[2].set_yscale('log')

# %%
M_edge
# Out:
# array([0.00000000e+00, 6.66000500e-07, 7.25219405e-07, 7.91456816e-07,
#        8.65544047e-07, 9.48410785e-07, 1.04109671e-06, 1.14476451e-06,
#        1.26071436e-06, 1.39040022e-06, 1.53544794e-06, 1.69767557e-06,
#        1.87911600e-06, 2.08204233e-06, 2.30899620e-06, 2.56281937e-06,
#        2.84668915e-06, 3.16415784e-06, 3.51919695e-06, 3.91624640e-06,
#        4.36026972e-06, 4.85681549e-06, 5.41208611e-06, 6.03301452e-06,
#        6.72734994e-06, 7.50375351e-06, 8.37190518e-06, 9.34262297e-06,
#        1.04279961e-05, 1.16415334e-05, 1.29983296e-05, 1.45152497e-05,
#        1.62111358e-05, 1.81070369e-05, 2.02264662e-05, 2.25956867e-05,
#        2.52440307e-05, 2.82042554e-05, 3.15129392e-05, 3.52109231e-05,
#        3.93438031e-05, 4.39624772e-05, 4.91237555e-05, 5.48910389e-05,
#        6.13350740e-05, 6.85347929e-05, 7.65782469e-05, 8.55636449e-05,
#        9.56005061e-05, 1.06810941e-04, 1.19331075e-04, 1.33312623e-04,
#        1.48924643e-04, 1.66355476e-04, 1.85814897e-04, 2.07536492e-04,
#        2.31780301e-04, 2.58835728e-04, 2.89024764e-04, 3.22705551e-04,
#        3.60276305e-04, 4.02179655e-04, 4.48907415e-04, 5.01005844e-04,
